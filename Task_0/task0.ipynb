# %% [markdown]
# <div>
# <img src="images/question_darkblue.png" align="left" width="24" height="24"/>
# <span style="line-height:24px; margin-left: 0.5em"><font color="darkblue">Please note down all your findings at this stage before you continue.</font></span>
# </div>

# %% [markdown]
# <div>
# <img src="images/hint_darkblue.png" align="left" width="24" height="24"/>
# <span style="line-height:24px; margin-left: 0.5em"><font color="darkblue">Feel free to add your own conversion and helper functions if necessary.</font></span>
# </div>
# </div>

# %% [markdown]
# <div>
# <img src="images/write_chocolate.png" align="left" width="24" height="24"/>
# <span style="line-height:24px; margin-left: 0.5em"><font color='Chocolate'>
# <b> Please fill in with your own observations </b>
# </font></span>
# </div>

# %% [markdown]
# Well, we haven' gotten the chip yet. so no connectioontest can be done!

# %% [markdown]
# <font color="darkgreen">
# <details>
# <summary>
# <div>
# <img src="images/hint_darkgreen.png" align="left" width="24" height="24"/>
# <span style="line-height:24px; margin-left: 0.5em">
# <b>Click to show hints</b>
# </span>
# </div>
# </summary>
#
# 1. Look at the slides from the lecture and ask yourself: Would it be possible to create this kind of data with this cipher?<br>
# 2. Is there a type of cipher that you can rule out from the beginning?
#
# </details></font>

# %%
! jupyter contrib nbextension install --user
# Out:
# [I 08:24:47 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 08:24:47 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 08:24:47 InstallContribNbextensionsApp] Installing C:\Users\ludwi\AppData\Local\Programs\Python\Python310\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore -> addbefore
# [I 08:24:47 InstallContribNbextensionsApp] Up to date: C:\Users\ludwi\AppData\Roaming\jupyter\nbextensions\addbefore\addbefore.yaml
# [I 08:24:47 InstallContribNbextensionsApp] Up to date: C:\Users\ludwi\AppData\Roaming\jupyter\nbextensions\addbefore\icon.png
# [I 08:24:47 InstallContribNbextensionsApp] Up to date: C:\Users\ludwi\AppData\Roaming\jupyter\nbextensions\addbefore\main.js
# [I 08:24:47 InstallContribNbextensionsApp] Up to date: C:\Users\ludwi\AppData\Roaming\jupyter\nbextensions\addbefore\readme.md
# [I 08:24:47 InstallContribNbextensionsApp] - Validating: ok
# ...

# %%
! jupyter nbextension enable Freeze/Main --user
! jupyter nbextension enable Codefolding/Main --user
! jupyter nbextension enable Collapsible\ Headings/Main --user
# Out:
# Enabling notebook extension Freeze/Main...
#       - Validating: ok
# Enabling notebook extension Codefolding/Main...
#       - Validating: ok
# Please specify one nbextension/package at a time
